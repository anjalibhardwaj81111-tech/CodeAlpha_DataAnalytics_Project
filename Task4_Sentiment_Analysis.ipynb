# %%
# !pip install textblob
# Out:
# Collecting textblob
#   Downloading textblob-0.20.0-py3-none-any.whl.metadata (4.0 kB)
# Collecting nltk>=3.9 (from textblob)
#   Downloading nltk-3.9.4-py3-none-any.whl.metadata (3.2 kB)
# Collecting click (from nltk>=3.9->textblob)
#   Downloading click-8.3.3-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: joblib in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from nltk>=3.9->textblob) (1.5.2)
# Collecting regex>=2021.8.3 (from nltk>=3.9->textblob)
#   Downloading regex-2026.5.9-cp314-cp314-win_amd64.whl.metadata (41 kB)
# Collecting tqdm (from nltk>=3.9->textblob)
#   Downloading tqdm-4.67.3-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: colorama in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from click->nltk>=3.9->textblob) (0.4.6)
# Downloading textblob-0.20.0-py3-none-any.whl (624 kB)
#    ---------------------------------------- 0.0/625.0 kB ? eta -:--:--
#    ---------------------------------------- 625.0/625.0 kB 5.1 MB/s  0:00:00
# Downloading nltk-3.9.4-py3-none-any.whl (1.6 MB)
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    --------------------------------- ------ 1.3/1.6 MB 7.1 MB/s eta 0:00:01
#    ---------------------------------------- 1.6/1.6 MB 6.3 MB/s  0:00:00
# Downloading regex-2026.5.9-cp314-cp314-win_amd64.whl (280 kB)
# Downloading click-8.3.3-py3-none-any.whl (110 kB)
# Downloading tqdm-4.67.3-py3-none-any.whl (78 kB)
# Installing collected packages: tqdm, regex, click, nltk, textblob
#
#    ---------------------------------------- 0/5 [tqdm]
#    ---------------------------------------- 0/5 [tqdm]
#    -------- ------------------------------- 1/5 [regex]
#    ---------------- ----------------------- 2/5 [click]
#    ---------------- ----------------------- 2/5 [click]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    -------------------------------- ------- 4/5 [textblob]
#    -------------------------------- ------- 4/5 [textblob]
#    ---------------------------------------- 5/5 [textblob]
#
# Successfully installed click-8.3.3 nltk-3.9.4 regex-2026.5.9 textblob-0.20.0 tqdm-4.67.3

# %%
import pandas as pd
from textblob import TextBlob
import matplotlib.pyplot as plt

# %%
data = {
    'Review': [
        'This product is amazing',
        'Very bad quality',
        'Excellent service',
        'Worst experience ever',
        'I love this item',
        'Not worth the money',
        'Fantastic purchase',
        'Terrible customer support'
    ]
}

df = pd.DataFrame(data)

df
# Out:
#                       Review
# 0    This product is amazing
# 1           Very bad quality
# 2          Excellent service
# 3      Worst experience ever
# 4           I love this item
# 5        Not worth the money
# 6         Fantastic purchase
# 7  Terrible customer support

# %%
def get_sentiment(text):
    
    analysis = TextBlob(text)
    
    if analysis.sentiment.polarity > 0:
        return 'Positive'
    
    elif analysis.sentiment.polarity < 0:
        return 'Negative'
    
    else:
        return 'Neutral'

# %%
df['Sentiment'] = df['Review'].apply(get_sentiment)

df
# Out:
#                       Review Sentiment
# 0    This product is amazing  Positive
# 1           Very bad quality  Negative
# 2          Excellent service  Positive
# 3      Worst experience ever  Negative
# 4           I love this item  Positive
# 5        Not worth the money  Negative
# 6         Fantastic purchase  Positive
# 7  Terrible customer support  Negative

# %%
sentiment_count = df['Sentiment'].value_counts()

sentiment_count
# Out:
# Sentiment
# Positive    4
# Negative    4
# Name: count, dtype: int64

# %%
sentiment_count.plot(kind='bar')

plt.title("Sentiment Analysis Results")

plt.xlabel("Sentiment")

plt.ylabel("Count")

plt.show()

# %%
plt.figure(figsize=(6,6))

plt.pie(sentiment_count.values,
        labels=sentiment_count.index,
        autopct='%1.1f%%')

plt.title("Sentiment Distribution")

plt.show()

# %% [markdown]
# 1. Positive reviews indicate customer satisfaction.
# 2. Negative reviews help identify product/service issues.
# 3. Sentiment analysis helps businesses improve customer experience.
