# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# df = pd.read_csv("OnlineRetail.csv", encoding='latin1')

# %%
df = pd.read_csv(r"C:\Users\Anjali Bhardwaz\OneDrive\Desktop\DesktopCodeAlpha_Project\OnlineRetail.csv", encoding='latin1')

# %% [markdown]
# df = pd.read_csv("OnlineRetail.csv", encoding='latin1')

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
df.shape
# Out:
# (541909, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB

# %%
df.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(5268)

# %%
df.drop_duplicates(inplace=True)

# %%
df.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  536641.000000  536641.000000  401604.000000
# mean        9.620029       4.632656   15281.160818
# std       219.130156      97.233118    1714.006089
# min    -80995.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   13939.000000
# 50%         3.000000       2.080000   15145.000000
# 75%        10.000000       4.130000   16784.000000
# max     80995.000000   38970.000000   18287.000000

# %%
df['TotalSales'] = df['Quantity'] * df['UnitPrice']

# %%
df['TotalSales'].sum()
# Out:
# np.float64(9726006.954)

# %%
top_products = df.groupby('Description')['Quantity'].sum().sort_values(ascending=False).head(10)

top_products
# Out:
# Description
# WORLD WAR 2 GLIDERS ASSTD DESIGNS     53751
# JUMBO BAG RED RETROSPOT               47260
# POPCORN HOLDER                        36322
# ASSORTED COLOUR BIRD ORNAMENT         36282
# PACK OF 72 RETROSPOT CAKE CASES       36016
# WHITE HANGING HEART T-LIGHT HOLDER    35298
# RABBIT NIGHT LIGHT                    30631
# MINI PAINT SET VINTAGE                26437
# PACK OF 12 LONDON TISSUES             26299
# PACK OF 60 PINK PAISLEY CAKE CASES    24719
# Name: Quantity, dtype: int64

# %%
country_sales = df.groupby('Country')['TotalSales'].sum().sort_values(ascending=False).head(10)

country_sales
# Out:
# Country
# United Kingdom    8167128.184
# Netherlands        284661.540
# EIRE               262993.380
# Germany            221509.470
# France             197317.110
# Australia          137009.770
# Switzerland         56363.050
# Spain               54756.030
# Belgium             40910.960
# Sweden              36585.410
# Name: TotalSales, dtype: float64

# %%
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'])

# %%
monthly_sales = df.groupby(df['InvoiceDate'].dt.month)['TotalSales'].sum()

monthly_sales
# Out:
# InvoiceDate
# 1      558448.560
# 2      497026.410
# 3      682013.980
# 4      492367.841
# 5      722094.100
# 6      689977.230
# 7      680156.991
# 8      681386.460
# 9     1017596.682
# 10    1069368.230
# 11    1456145.800
# 12    1179424.670
# Name: TotalSales, dtype: float64

# %%
plt.figure(figsize=(12,5))

top_products.plot(kind='bar')

plt.title("Top Selling Products")

plt.xlabel("Products")

plt.ylabel("Quantity")

plt.show()

# %%
plt.figure(figsize=(12,5))

country_sales.plot(kind='bar')

plt.title("Top Countries By Sales")

plt.xlabel("Country")

plt.ylabel("Sales")

plt.show()

# %%
plt.figure(figsize=(10,5))

monthly_sales.plot()

plt.title("Monthly Sales Trend")

plt.xlabel("Month")

plt.ylabel("Sales")

plt.show()

# %%
sns.heatmap(df.corr(numeric_only=True), annot=True)

plt.show()

# %% [markdown]
# 1. United Kingdom generated highest sales.
# 2. Some products are sold more frequently.
# 3. Sales increase during festive seasons.
# 4. High-value customers contribute major revenue.
# 5. Dataset contains important business insights.

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\Anjali Bhardwaz\OneDrive\Desktop\DesktopCodeAlpha_Project\cleaned_online_retail.csv")

small_df = df.head(10000)

small_df.to_csv("cleaned_online_retail_small.csv", index=False)

print("Small file created!")
# Out:
# Small file created!
